# %% [markdown]
# <h2>Mobile Price Data Project: Notebook 1

# %% [markdown]
# <h3>Data Source and Import

# %%
import pandas as pd
import numpy as np
import os
from pathlib import Path

# %% [markdown]
# Data obtained here: https://www.kaggle.com/datasets/iabhishekofficial/mobile-price-classification

# %%
cwd_path = Path.cwd()
data_dir = Path('Mobile Price Dataset')

# %%
file_paths = [cwd_path / data_dir / 'test.csv', cwd_path / data_dir / 'train.csv']
# The data is provided pre split. I would like to woek with the whole dataset and split myself
raw_data_1 = pd.read_csv(file_paths[0])
raw_data_2 = pd.read_csv(file_paths[1])
# Merge
data = pd.concat([raw_data_1, raw_data_2], ignore_index=True)

# %%
print(data.shape)
data.head(10)
# Out:
# (3000, 22)
#      id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1.0           1043     1          1.8         1  14       0           5
# 1   2.0            841     1          0.5         1   4       1          61
# 2   3.0           1807     1          2.8         0   1       0          27
# 3   4.0           1546     0          0.5         1  18       1          25
# 4   5.0           1434     0          1.4         0  11       1          49
# 5   6.0           1464     1          2.9         1   5       1          50
# 6   7.0           1718     0          2.4         0   1       0          47
# 7   8.0            833     0          2.4         1   0       0          62
# 8   9.0           1111     1          2.9         1   9       1          25
# 9  10.0           1520     0          0.5         0   1       0          25
#
#    m_dep  mobile_wt  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# ...

# %% [markdown]
# <h3>EDA
